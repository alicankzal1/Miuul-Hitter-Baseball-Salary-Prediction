# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.float_format', lambda x: '%.2f' % x)
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings("ignore")

from helpers import *

# %%
df = pd.read_csv("hitters.csv")

# %%
check_df(df)
# Out:
# ##################### Shape #####################
# (322, 20)
# ##################### Types #####################
# AtBat          int64
# Hits           int64
# HmRun          int64
# Runs           int64
# RBI            int64
# Walks          int64
# Years          int64
# CAtBat         int64
# CHits          int64
# CHmRun         int64
# CRuns          int64
# CRBI           int64
# CWalks         int64
# League        object
# Division      object
# PutOuts        int64
# Assists        int64
# Errors         int64
# Salary       float64
# NewLeague     object
# dtype: object
# ##################### Head #####################
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10  475.00         N
# 2   266     263      A        W      880       82      14  480.00         A
# 3   838     354      N        E      200       11       3  500.00         N
# 4    46      33      N        E      805       40       4   91.50         N
# ##################### Tail #####################
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary  \
# 317    379   311     138      N        E      325        9       3  700.00
# 318    897   451     875      A        E      313      381      20  875.00
# 319    217    93     146      A        W       37      113       7  385.00
# 320    470   420     332      A        E     1314      131      12  960.00
# 321    775   357     249      A        W      408        4       3 1000.00
#
#     NewLeague
# 317         N
# 318         A
# 319         A
# 320         A
# 321         A
# ##################### NA #####################
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64
# ##################### Quantiles #####################
#          0.00   0.05    0.50    0.95    0.99     1.00
# AtBat   16.00 161.00  379.50  609.90  658.59   687.00
# Hits     1.00  39.00   96.00  174.00  210.79   238.00
# HmRun    0.00   0.00    8.00   28.95   33.00    40.00
# Runs     0.00  17.00   48.00   94.00  107.79   130.00
# RBI      0.00  14.00   44.00   96.00  112.37   121.00
# Walks    0.00  11.05   35.00   78.00   93.58   105.00
# Years    1.00   1.00    6.00   17.00   19.79    24.00
# CAtBat  19.00 216.50 1928.00 7125.60 8749.97 14053.00
# CHits    4.00  54.00  508.00 2017.15 2500.34  4256.00
# CHmRun   0.00   2.00   37.50  265.65  373.12   548.00
# CRuns    1.00  27.00  247.00 1032.30 1174.37  2165.00
# CRBI     0.00  22.05  220.50 1071.75 1310.85  1659.00
# CWalks   0.00  15.05  170.50  817.60 1139.14  1566.00
# PutOuts  0.00  33.20  212.00  910.65 1301.19  1378.00
# Assists  0.00   0.00   39.50  431.45  478.16   492.00
# Errors   0.00   0.00    6.00   20.00   25.79    32.00
# Salary  67.50  86.60  425.00 1346.00 2032.89  2460.00

# %%
cat_cols,num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 322
# Variables: 20
# cat_cols: 3
# num_cols: 17
# cat_but_car: 0
# num_but_cat: 0

# %%
print(f"Categorical Columns -> {cat_cols}\nNumerical Columns -> {num_cols}\nCardinal Columns -> {cat_but_car}")
# Out:
# Categorical Columns -> ['League', 'Division', 'NewLeague']
# Numerical Columns -> ['AtBat', 'Hits', 'HmRun', 'Runs', 'RBI', 'Walks', 'Years', 'CAtBat', 'CHits', 'CHmRun', 'CRuns', 'CRBI', 'CWalks', 'PutOuts', 'Assists', 'Errors', 'Salary']
# Cardinal Columns -> []

# %% [markdown]
# # Outliers

# %%
for col in num_cols:
    print(col, check_outlier(df,col))
# Out:
# AtBat False
# Hits False
# HmRun True
# Runs True
# RBI True
# Walks True
# Years True
# CAtBat True
# CHits True
# CHmRun True
# CRuns True
# CRBI True
# CWalks True
# PutOuts True
# Assists True
# Errors True
# Salary True

# %%
for col in num_cols:
    plt.title(col)
    sns.boxplot(df[col])
    plt.show(block=True)

# %%
for col in num_cols:
    print(col, check_outlier(df, col))
# Out:
# AtBat False
# Hits False
# HmRun True
# Runs True
# RBI True
# Walks True
# Years True
# CAtBat True
# CHits True
# CHmRun True
# CRuns True
# CRBI True
# CWalks True
# PutOuts True
# Assists True
# Errors True
# Salary True

# %%
for col in num_cols:
    if check_outlier(df, col, q1= 0.1, q3= 0.9):
        replace_with_thresholds(df, col, q1= 0.1, q3= 0.9)

# %% [markdown]
# # Analysis of Categorical Variables

# %%
for col in cat_cols:
    cat_summary(df, col, plot= True)
# Out:
#    League  Ratio
# A     175  54.35
# N     147  45.65
# ##########################################
#    Division  Ratio
# W       165  51.24
# E       157  48.76
# ##########################################
#    NewLeague  Ratio
# A        176  54.66
# N        146  45.34
# ##########################################

# %% [markdown]
# # Analysis of Numerical Variables

# %%
for col in num_cols:
    num_summary(df, col, plot= True)
# Out:
# count   322.00
# mean    380.93
# std     153.40
# min      16.00
# 5%      161.00
# 10%     194.10
# 20%     221.80
# 30%     281.30
# 40%     321.80
# 50%     379.50
# 60%     430.20
# 70%     490.00
# 80%     535.60
# 90%     584.90
# 95%     609.90
# 99%     658.59
# max     687.00
# Name: AtBat, dtype: float64
# count   322.00
# mean    101.02
# std      46.45
# min       1.00
# 5%       39.00
# 10%      45.10
# 20%      57.00
# 30%      70.00
# 40%      82.00
# 50%      96.00
# 60%     113.00
# 70%     128.70
# 80%     144.00
# 90%     163.00
# 95%     174.00
# 99%     210.79
# max     238.00
# Name: Hits, dtype: float64
# count   322.00
# mean     10.77
# std       8.71
# min       0.00
# 5%        0.00
# 10%       1.00
# 20%       3.00
# 30%       5.00
# 40%       6.00
# 50%       8.00
# 60%      10.60
# 70%      14.00
# 80%      18.00
# 90%      24.00
# 95%      28.95
# 99%      33.00
# max      40.00
# Name: HmRun, dtype: float64
# count   322.00
# mean     50.91
# std      26.02
# min       0.00
# 5%       17.00
# 10%      20.10
# 20%      27.00
# 30%      33.00
# 40%      41.00
# 50%      48.00
# 60%      55.60
# 70%      66.00
# 80%      75.80
# 90%      89.00
# 95%      94.00
# 99%     107.79
# max     130.00
# Name: Runs, dtype: float64
# count   322.00
# mean     48.03
# std      26.17
# min       0.00
# 5%       14.00
# 10%      19.00
# 20%      26.00
# 30%      30.00
# 40%      36.40
# 50%      44.00
# 60%      49.00
# 70%      58.00
# 80%      73.00
# 90%      86.00
# 95%      96.00
# 99%     112.37
# max     121.00
# Name: RBI, dtype: float64
# count   322.00
# mean     38.74
# std      21.64
# min       0.00
# 5%       11.05
# 10%      15.00
# 20%      20.00
# 30%      24.00
# 40%      30.00
# 50%      35.00
# 60%      40.00
# 70%      48.70
# 80%      59.00
# 90%      69.90
# 95%      78.00
# 99%      93.58
# max     105.00
# Name: Walks, dtype: float64
# count   322.00
# mean      7.44
# std       4.93
# min       1.00
# 5%        1.00
# 10%       2.00
# 20%       3.00
# 30%       4.00
# 40%       5.00
# 50%       6.00
# 60%       7.60
# 70%      10.00
# 80%      12.00
# 90%      15.00
# 95%      17.00
# 99%      19.79
# max      24.00
# Name: Years, dtype: float64
# count     322.00
# mean     2648.68
# std      2324.21
# min        19.00
# 5%        216.50
# 10%       342.20
# 20%       667.60
# 30%       963.40
# 40%      1402.20
# 50%      1928.00
# 60%      2654.00
# 70%      3365.00
# 80%      4483.00
# 90%      6123.40
# 95%      7125.60
# 99%      8749.97
# max     14053.00
# Name: CAtBat, dtype: float64
# count    322.00
# mean     716.84
# std      650.62
# min        4.00
# 5%        54.00
# 10%       86.00
# 20%      164.60
# 30%      238.00
# 40%      355.80
# 50%      508.00
# 60%      708.20
# 70%      911.10
# 80%     1229.20
# 90%     1659.60
# 95%     2017.15
# 99%     2500.34
# max     4020.00
# Name: CHits, dtype: float64
# count   322.00
# mean     69.28
# std      85.19
# min       0.00
# 5%        2.00
# 10%       4.00
# 20%      10.20
# 30%      16.30
# 40%      27.40
# 50%      37.50
# 60%      51.20
# 70%      72.40
# 80%     103.80
# 90%     194.90
# 95%     265.65
# 99%     373.12
# max     481.25
# Name: CHmRun, dtype: float64
# count    322.00
# mean     358.80
# std      334.11
# min        1.00
# 5%        27.00
# 10%       38.10
# 20%       80.40
# 30%      117.30
# 40%      181.00
# 50%      247.00
# 60%      333.00
# 70%      443.40
# 80%      627.20
# 90%      895.70
# 95%     1032.30
# 99%     1174.37
# max     2165.00
# Name: CRuns, dtype: float64
# count    322.00
# mean     330.12
# std      333.22
# min        0.00
# 5%        22.05
# 10%       34.10
# 20%       70.20
# 30%      106.30
# 40%      149.00
# 50%      220.50
# 60%      303.60
# 70%      379.10
# 80%      496.20
# 90%      861.60
# 95%     1071.75
# 99%     1310.85
# max     1659.00
# Name: CRBI, dtype: float64
# count    322.00
# mean     260.23
# std      267.04
# min        0.00
# 5%        15.05
# 10%       30.10
# 20%       55.00
# 30%       82.00
# 40%      117.40
# 50%      170.50
# 60%      226.60
# 70%      300.70
# 80%      421.00
# 90%      643.90
# 95%      817.60
# 99%     1139.14
# max     1564.60
# Name: CWalks, dtype: float64
# count    322.00
# mean     288.94
# std      280.70
# min        0.00
# 5%        33.20
# 10%       62.20
# 20%       99.60
# 30%      132.00
# 40%      167.00
# 50%      212.00
# 60%      257.40
# 70%      303.00
# 80%      365.80
# 90%      685.60
# 95%      910.65
# 99%     1301.19
# max     1378.00
# Name: PutOuts, dtype: float64
# count   322.00
# mean    106.91
# std     136.85
# min       0.00
# 5%        0.00
# 10%       2.00
# 20%       5.20
# 30%       9.00
# 40%      15.40
# 50%      39.50
# 60%      76.80
# 70%     134.80
# 80%     210.80
# 90%     353.30
# 95%     431.45
# 99%     478.16
# max     492.00
# Name: Assists, dtype: float64
# count   322.00
# mean      8.04
# std       6.37
# min       0.00
# 5%        0.00
# 10%       1.00
# 20%       3.00
# 30%       4.00
# 40%       5.00
# 50%       6.00
# 60%       8.00
# 70%      10.00
# 80%      13.00
# 90%      17.00
# 95%      20.00
# 99%      25.79
# max      32.00
# Name: Errors, dtype: float64
# count    263.00
# mean     535.93
# std      451.12
# min       67.50
# 5%        86.60
# 10%      100.00
# 20%      155.00
# 30%      221.00
# 40%      300.00
# 50%      425.00
# 60%      538.00
# 70%      700.00
# 80%      809.00
# 90%     1048.67
# 95%     1346.00
# 99%     2032.89
# max     2460.00
# Name: Salary, dtype: float64

# %% [markdown]
# # Analysis of Target Variable

# %%
for col in cat_cols:
    target_summary_with_cat(df, "Salary", col)
# Out:
#         TARGET_MEAN
# League
# A            542.00
# N            529.12
#
#
#           TARGET_MEAN
# Division
# E              624.27
# W              450.88
#
#
#            TARGET_MEAN
# NewLeague
# A               537.11
# N               534.55

# %% [markdown]
# # Analysis of Correlation

# %%
corr = df.corr().abs()
sns.set(rc={'figure.figsize': (15, 10)})
sns.heatmap(corr, cmap="RdBu", annot=True)
plt.show(block=True)

# %%
df.isnull().sum()
# Out:
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %%
df.dropna(inplace= True)
df.isnull().sum()
# Out:
# AtBat        0
# Hits         0
# HmRun        0
# Runs         0
# RBI          0
# Walks        0
# Years        0
# CAtBat       0
# CHits        0
# CHmRun       0
# CRuns        0
# CRBI         0
# CWalks       0
# League       0
# Division     0
# PutOuts      0
# Assists      0
# Errors       0
# Salary       0
# NewLeague    0
# dtype: int64

# %% [markdown]
# # Feature Extraction

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 263
# Variables: 20
# cat_cols: 3
# num_cols: 17
# cat_but_car: 0
# num_but_cat: 0

# %%
new_num_cols = [col for col in num_cols if col not in ["Salary", "Years"]]
new_num_cols
# Out:
# ['AtBat',
#  'Hits',
#  'HmRun',
#  'Runs',
#  'RBI',
#  'Walks',
#  'CAtBat',
#  'CHits',
#  'CHmRun',
#  'CRuns',
#  'CRBI',
#  'CWalks',
#  'PutOuts',
#  'Assists',
#  'Errors']

# %%
df[new_num_cols] = df[new_num_cols] + 1

# %%
df.columns = [col.upper() for col in df.columns]

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 263
# Variables: 20
# cat_cols: 3
# num_cols: 17
# cat_but_car: 0
# num_but_cat: 0

# %%
# RATIO OF VARIABLES

# CAREER RUNS RATIO
df["NEW_C_RUNS_RATIO"] = df["RUNS"] / df["CRUNS"]
# CAREER BAT RATIO
df["NEW_C_ATBAT_RATIO"] = df["ATBAT"] / df["CATBAT"]
# CAREER HITS RATIO
df["NEW_C_HITS_RATIO"] = df["HITS"] / df["CHITS"]
# CAREER HMRUN RATIO
df["NEW_C_HMRUN_RATIO"] = df["HMRUN"] / df["CHMRUN"]
# CAREER RBI RATIO
df["NEW_C_RBI_RATIO"] = df["RBI"] / df["CRBI"]
# CAREER WALKS RATIO
df["NEW_C_WALKS_RATIO"] = df["WALKS"] / df["CWALKS"]
df["NEW_C_HIT_RATE"] = df["CHITS"] / df["CATBAT"]
# PLAYER TYPE : RUNNER
df["NEW_C_RUNNER"] = df["CRBI"] / df["CHITS"]
# PLAYER TYPE : HIT AND RUN
df["NEW_C_HIT-AND-RUN"] = df["CRUNS"] / df["CHITS"]
# MOST VALUABLE HIT RATIO IN HITS
df["NEW_C_HMHITS_RATIO"] = df["CHMRUN"] / df["CHITS"]
# MOST VALUABLE HIT RATIO IN ALL SHOTS
df["NEW_C_HMATBAT_RATIO"] = df["CATBAT"] / df["CHMRUN"]

# %%
#Annual Averages
df["NEW_CATBAT_MEAN"] = df["CATBAT"] / df["YEARS"]
df["NEW_CHITS_MEAN"] = df["CHITS"] / df["YEARS"]
df["NEW_CHMRUN_MEAN"] = df["CHMRUN"] / df["YEARS"]
df["NEW_CRUNS_MEAN"] = df["CRUNS"] / df["YEARS"]
df["NEW_CRBI_MEAN"] = df["CRBI"] / df["YEARS"]
df["NEW_CWALKS_MEAN"] = df["CWALKS"] / df["YEARS"]

# %%
# PLAYER LEVEL
df.loc[(df["YEARS"] <= 2), "NEW_YEARS_LEVEL"] = "Junior"
df.loc[(df["YEARS"] > 2) & (df['YEARS'] <= 5), "NEW_YEARS_LEVEL"] = "Mid"
df.loc[(df["YEARS"] > 5) & (df['YEARS'] <= 10), "NEW_YEARS_LEVEL"] = "Senior"
df.loc[(df["YEARS"] > 10), "NEW_YEARS_LEVEL"] = "Expert"

# %%
# PLAYER LEVEL X DIVISION

df.loc[(df["NEW_YEARS_LEVEL"] == "Junior") & (df["DIVISION"] == "E"), 'NEW_DIV_CAT'] = "Junior-East"
df.loc[(df["NEW_YEARS_LEVEL"] == "Junior") & (df["DIVISION"] == "W"), 'NEW_DIV_CAT'] = "Junior-West"
df.loc[(df["NEW_YEARS_LEVEL"] == "Mid") & (df["DIVISION"] == "E"), 'NEW_DIV_CAT'] = "Mid-East"
df.loc[(df["NEW_YEARS_LEVEL"] == "Mid") & (df["DIVISION"] == "W"), 'NEW_DIV_CAT'] = "Mid-West"
df.loc[(df["NEW_YEARS_LEVEL"] == "Senior") & (df["DIVISION"] == "E"), 'NEW_DIV_CAT'] = "Senior-East"
df.loc[(df["NEW_YEARS_LEVEL"] == "Senior") & (df["DIVISION"] == "W"), 'NEW_DIV_CAT'] = "Senior-West"
df.loc[(df["NEW_YEARS_LEVEL"] == "Expert") & (df["DIVISION"] == "E"), 'NEW_DIV_CAT'] = "Expert-East"
df.loc[(df["NEW_YEARS_LEVEL"] == "Expert") & (df["DIVISION"] == "W"), 'NEW_DIV_CAT'] = "Expert-West"

# %%
# Player Promotion to Next League
df.loc[(df["LEAGUE"] == "N") & (df["NEWLEAGUE"] == "N"), "NEW_PLAYER_PROGRESS"] = "StandN"
df.loc[(df["LEAGUE"] == "A") & (df["NEWLEAGUE"] == "A"), "NEW_PLAYER_PROGRESS"] = "StandA"
df.loc[(df["LEAGUE"] == "N") & (df["NEWLEAGUE"] == "A"), "NEW_PLAYER_PROGRESS"] = "Descend"
df.loc[(df["LEAGUE"] == "A") & (df["NEWLEAGUE"] == "N"), "NEW_PLAYER_PROGRESS"] = "Ascend"

# %%
len(cat_cols)
# Out:
# 3

# %%
len(num_cols)
# Out:
# 17

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 263
# Variables: 40
# cat_cols: 6
# num_cols: 34
# cat_but_car: 0
# num_but_cat: 0

# %% [markdown]
# # Encoding

# %% [markdown]
# ### Label Encoding

# %%
binary_cols = [col for col in df.columns if
              df[col].dtype not in [int, float] and df[col].nunique() == 2]

# %%
for col in binary_cols:
    df = label_encoder(df, col)

# %%
df
# Out:
#      ATBAT  HITS  HMRUN  RUNS  RBI  WALKS  YEARS  CATBAT   CHITS  CHMRUN  ...  \
# 1      316    82      8    25   39     40     14    3450  836.00   70.00  ...
# 2      480   131     19    67   73     77      3    1625  458.00   64.00  ...
# 3      497   142     21    66   79     38     11    5629 1576.00  226.00  ...
# 4      322    88     11    40   43     31      2     397  102.00   13.00  ...
# 5      595   170      5    75   52     36     11    4409 1134.00   20.00  ...
# ..     ...   ...    ...   ...  ...    ...    ...     ...     ...     ...  ...
# 317    498   128      8    66   49     38      5    2704  807.00   33.00  ...
# 318    493   137      6    77   51     95     12    5512 1512.00   40.00  ...
# 319    476   127      4    62   44     53      6    1701  434.00    8.00  ...
# 320    574   145     10    86   61     79      8    3199  858.00   98.00  ...
# 321    632   171     10    78   45     32     11    4909 1458.00   31.00  ...
#
#      NEW_C_HMATBAT_RATIO  NEW_CATBAT_MEAN  NEW_CHITS_MEAN  NEW_CHMRUN_MEAN  \
# 1                  49.29           246.43           59.71             5.00
# 2                  25.39           541.67          152.67            21.33
# 3                  24.91           511.73          143.27            20.55
# 4                  30.54           198.50           51.00             6.50
# 5                 220.45           400.82          103.09             1.82
# ..                   ...              ...             ...              ...
# 317                81.94           540.80          161.40             6.60
# 318               137.80           459.33          126.00             3.33
# 319               212.62           283.50           72.33             1.33
# 320                32.64           399.88          107.25            12.25
# 321               158.35           446.27          132.55             2.82
#
#      NEW_CRUNS_MEAN  NEW_CRBI_MEAN  NEW_CWALKS_MEAN  NEW_YEARS_LEVEL  \
# 1             23.00          29.64            26.86           Expert
# 2             75.00          89.00            88.00              Mid
# 3             75.36          76.27            32.27           Expert
# 4             24.50          23.50            17.00           Junior
# 5             45.64          30.64            17.73           Expert
# ..              ...            ...              ...              ...
# 317           76.00          62.40            27.80              Mid
# 318           74.83          37.67            73.00           Expert
# 319           36.33          15.67            24.50           Senior
# 320           58.88          52.62            41.62           Senior
# 321           70.55          32.55            22.73           Expert
#
#      NEW_DIV_CAT  NEW_PLAYER_PROGRESS
# 1    Expert-West               StandN
# 2       Mid-West               StandA
# 3    Expert-East               StandN
# 4    Junior-East               StandN
# 5    Expert-West               StandA
# ..           ...                  ...
# 317     Mid-East               StandN
# 318  Expert-East               StandA
# 319  Senior-West               StandA
# 320  Senior-East               StandA
# 321  Expert-West               StandA
#
# [263 rows x 40 columns]

# %% [markdown]
# ### Rare Encoding

# %%
rare_analyser(df, "SALARY", cat_cols)
df = rare_encoder(df, 0.01, cat_cols)
# Out:
# LEAGUE : 2
#    COUNT  RATIO  TARGET_MEAN
# 0    139   0.53       542.00
# 1    124   0.47       529.12
#
#
# DIVISION : 2
#    COUNT  RATIO  TARGET_MEAN
# 0    129   0.49       624.27
# 1    134   0.51       450.88
#
#
# NEWLEAGUE : 2
#    COUNT  RATIO  TARGET_MEAN
# 0    141   0.54       537.11
# 1    122   0.46       534.55
#
#
# NEW_YEARS_LEVEL : 4
#         COUNT  RATIO  TARGET_MEAN
# Expert     65   0.25       755.11
# Junior     38   0.14       186.92
# Mid        78   0.30       359.34
# Senior     82   0.31       691.89
#
#
# NEW_DIV_CAT : 8
#              COUNT  RATIO  TARGET_MEAN
# Expert-East     32   0.12       809.78
# Expert-West     33   0.13       702.10
# Junior-East     16   0.06       229.30
# Junior-West     22   0.08       156.09
# Mid-East        37   0.14       427.91
# Mid-West        41   0.16       297.46
# Senior-East     44   0.17       798.11
# Senior-West     38   0.14       568.90
#
#
# NEW_PLAYER_PROGRESS : 4
#          COUNT  RATIO  TARGET_MEAN
# Ascend       8   0.03       558.12
# Descend     10   0.04       486.00
# StandA     131   0.50       541.01
# StandN     114   0.43       532.90

# %% [markdown]
# ### One Hot Encoding

# %%
ohe_cols = [col for col in df.columns if 10 >= df[col].nunique() > 2]
df = one_hot_encoder(df, ohe_cols,drop_first= True)

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
num_cols.remove("SALARY")
# Out:
# Observations: 263
# Variables: 50
# cat_cols: 16
# num_cols: 34
# cat_but_car: 0
# num_but_cat: 16

# %% [markdown]
# ### Robust Scaler

# %%
for col in num_cols:
    transformer = RobustScaler().fit(df[[col]])
    df[col] = transformer.transform(df[[col]])

# %% [markdown]
# # Multiple Linear Regression

# %%
X = df.drop("SALARY", axis= 1)
y = df["SALARY"]

# %%
# Model
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.20, random_state= 1)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg_model.intercept_
# Out:
# 655.7646601452111

# %%
reg_model.coef_
# Out:
# array([-2.45997926e+02,  2.19272219e+02, -1.05385575e+02,  1.47336579e+02,
#         1.10859322e+02,  4.32869838e+01, -3.02517824e+02, -1.10356788e+03,
#         1.74893421e+03,  2.94324414e+02, -3.28619013e+02, -4.08426082e+02,
#         1.05960189e+02, -1.93076828e+01, -7.03900036e+01,  3.55076090e+01,
#        -3.54670064e+01,  6.26213136e+01,  4.23854891e+01, -3.15027673e+02,
#         1.25470910e+03, -1.05470783e+03,  7.98095426e+01, -2.88847140e+02,
#        -4.25060562e+01, -1.85472986e+02, -1.79538629e+00, -2.76695076e+01,
#        -5.94720503e+01,  1.36426473e+01, -1.28642956e+03,  7.74855474e+02,
#         1.84776526e+01,  2.73035290e+02,  3.30396695e+02, -2.22179798e+01,
#        -3.34730834e+01, -1.48627902e+02, -2.45509691e+01,  1.07972576e+00,
#        -2.63490781e+01, -7.12400530e+00, -1.10935926e+02, -3.76919756e+01,
#         2.10277936e+00, -2.66537485e+01, -1.73738702e+01, -2.50116189e+01,
#        -1.93381263e+00])

# %%
y_pred = reg_model.predict(X_train)

# %%
# Train RMSE

np.sqrt(mean_squared_error(y_train, y_pred))
# Out:
# 204.7164645682361

# %%
# Train R-squared score

reg_model.score(X_train, y_train)
# Out:
# 0.786256577366203

# %%
y_pred = reg_model.predict(X_test)

# %%
# Test RMSE
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 369.0526402145814

# %%
# Test R-squared score

reg_model.score(X_test, y_test)
# Out:
# 0.40532551579631804

# %% [markdown]
# ## 10 Fold Cross Validation

# %%
np.mean(np.sqrt(-cross_val_score(reg_model,
                                X,
                                y,
                                cv= 10,
                               scoring = "neg_mean_squared_error")))
# Out:
# 296.7354050455541
